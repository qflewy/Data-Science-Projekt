# %% [markdown]
# Test Notebook for DBscan
# created with the help of copilot

# %%
import polars as pl
import plotly.express as px
import numpy as np
from sklearn.cluster import DBSCAN

import sys
from pathlib import Path

project_root = Path().resolve().parent
sys.path.append(str(project_root))

from skripts.dbscanCompetitionDensity import getCSVData
from skripts.dbscanCompetitionDensity import plotClusters
from skripts.dbscanCompetitionDensity import performDBSCAN
from skripts.dbscanCompetitionDensity import create_CSV_with_cluster_labels
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[18], line 15
#      13 from skripts.dbscanCompetitionDensity import plotClusters
#      14 from skripts.dbscanCompetitionDensity import performDBSCAN
# ---> 15 from skripts.dbscanCompetitionDensity import create_CSV_with_cluster_labels
#
# ImportError: cannot import name 'create_CSV_with_cluster_labels' from 'skripts.dbscanCompetitionDensity' (C:\Users\Bjarne\Desktop\Uni\Data Science Projekt\Data-Science-Projekt\skripts\dbscanCompetitionDensity.py)

# %%
df = getCSVData("C:\\Users\\Bjarne\\Desktop\\Uni\\Data Science Projekt\\PersonalTesting\\dbscan\\stations.csv")
# Out:
# shape: (15_442, 3)
# ┌─────────────────────────────────┬───────────┬───────────┐
# │ uuid                            ┆ latitude  ┆ longitude │
# │ ---                             ┆ ---       ┆ ---       │
# │ str                             ┆ f64       ┆ f64       │
# ╞═════════════════════════════════╪═══════════╪═══════════╡
# │ 00060723-0001-4444-8888-acdc00… ┆ 49.296822 ┆ 9.661385  │
# │ 005056ba-7cb6-1ed2-bceb-5332ab… ┆ 53.74215  ┆ 9.94124   │
# │ 005056ba-7cb6-1ed2-bceb-573c18… ┆ 50.9618   ┆ 6.98007   │
# │ 005056ba-7cb6-1ed2-bceb-662ba1… ┆ 52.55016  ┆ 13.68212  │
# │ 005056ba-7cb6-1ed2-bceb-6f7b23… ┆ 51.48979  ┆ 6.78373   │
# │ …                               ┆ …         ┆ …         │
# │ c60a44f6-d495-4f49-ad0e-571e5d… ┆ 53.058803 ┆ 8.929957  │
# │ a64cabcf-c075-467c-8ff6-eec879… ┆ 52.3541   ┆ 14.0833   │
# │ c3181163-a8db-419a-8c63-b870c1… ┆ 51.0161   ┆ 10.119416 │
# │ 63ae4c8d-2f4d-4804-9e55-be7cff… ┆ 53.15205  ┆ 7.711785  │
# │ 00061715-accc-4444-8888-acdc00… ┆ 47.690041 ┆ 9.8288    │
# └─────────────────────────────────┴───────────┴───────────┘

# %%
labels = performDBSCAN(df, eps=0.02, min_samples=3)
figure = plotClusters(df, labels)
figure.show()
# Out:
# [ -1  -1   0 ... 850 655 875]
